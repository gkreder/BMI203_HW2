# %%
import gabe_hw2.cluster as cluster
from gabe_hw2.io import read_active_sites, write_clustering, write_mult_clusterings

# %%
active_sites = read_active_sites('data')
sim_matrix = cluster.get_sim_matrix(active_sites)
cluster.get_optimal_k(active_sites, sim_matrix)
# Out:
# Read in 136 active sites
